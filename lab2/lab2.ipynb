# %% [markdown]
# Parts of this assignment will be **automatically graded**. Please take note of the following:
# - Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
# - You can add additional cells, but it is not recommended to (re)move cells. Cells required for autograding cannot be moved and cells containing tests cannot be edited.
# - You are allowed to use a service such as [Google Colaboratory](https://colab.research.google.com/) to work together. However, you **cannot** hand in the notebook that was hosted on Google Colaboratory, but you need to copy your answers into the original notebook and verify that it runs succesfully offline. This is because Google Colaboratory destroys the metadata required for grading.
# - Name your notebook **exactly** `{TA_name}_{student1_id}_{student2_id}_lab{i}.ipynb`, for example `wouter_12345_67890_lab1.ipynb` (or elise or stephan, depending on your TA), **otherwise your submission will be skipped by our regex and you will get 0 points** (but no penalty as we cannot parse your student ids ;)).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your names below:

# %%
NAMES = "Davide Belli, Gabriele Cesa"

# %% [markdown]
# ---

# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
from tqdm import tqdm as _tqdm

def tqdm(*args, **kwargs):
    return _tqdm(*args, **kwargs, mininterval=1)  # Safety, do not overflow buffer

EPS = float(np.finfo(np.float32).eps)

assert sys.version_info[:3] >= (3, 6, 0), "Make sure you have Python 3.6 installed!"

# %% [markdown]
# ---
# ## 1. Deep Q-Network (DQN) (10 (+ 2 bonus) points)

# %%
import gym
env = gym.envs.make("CartPole-v0")

# %%
# env is a TimeLimit wrapper around an env, so use env.env to look into the env (but otherwise you can forget about this)
??env.env

# %%
import time
# The nice thing about the CARTPOLE is that it has very nice rendering functionality (if you are on a local environment). Let's have a look at an episode
obs = env.reset()
env.render()
done = False
while not done:
    obs, reward, done, _ = env.step(env.action_space.sample())
    env.render()
    time.sleep(0.05)
env.close()  # Close the environment or you will have a lot of render screens soon

# %% [markdown]
# Remember from the previous lab, that in order to optimize a policy we need to estimate the Q-values (e.g. estimate the *action* values). In the CartPole problem, our state is current position of the cart, the current velocity of the cart, the current (angular) position of the pole and the (angular) speed of the pole. As these are continuous variables, we have an infinite number of states (ignoring the fact that a digital computer can only represent finitely many states in finite memory).

# %% [markdown]
# Can you think of a way in which we can still use a tabular approach? Why would this work and can you think of an example problem where this would not work?

# %% [markdown]
# We can use binning (aggregation) to approximate the infinite number of possible states with a discrete number of states representing intervals over the features' domains.
#
# This approach will not work well when high resolution on the state is required to predict the action. An example could be a surgery robot, which needs to be very accurate in its movements and requires information about its position with very high precision. In these cases, shrinking the intervals associated to the states and, consecutively, increasing the number of states might not be sufficient: indeed, each state would be associated to much smaller intervals and, thus, will have a much smaller probability to be sampled making harder for the model to learn the policy in that state. Moreover, since each state is representated independently, it is harder to exploit the smoothness of the function used to approximate the policy (eg. a neural network) to generalize to states never seen but similar to the ones observed in the training.
# On the other hand, reducing the number of states by associating them larger intervals will make them not informative enough for predicting an optimal action, since not enough resolution would be provided.

# %% [markdown]
# ### 1.1 Implement Q-Network

# %% [markdown]
# We will not use the tabular approach but approximate the Q-value function by a general approximator function. We will skip the linear case and directly use a two layer Neural Network. We use [PyTorch](https://pytorch.org/) to implement the network, as this will allow us to train it easily later. We can implement a model using `torch.nn.Sequential`, but with PyTorch it is actually very easy to implement the model (e.g. the forward pass) from scratch. Now implement the `QNetwork.forward` function that uses one hidden layer with ReLU activation (no output activation).

# %%
import torch.nn.functional as F

class QNetwork(nn.Module):
    
    def __init__(self, num_hidden=128):
        nn.Module.__init__(self)
        self.l1 = nn.Linear(4, num_hidden)
        self.l2 = nn.Linear(num_hidden, 2)

    def forward(self, x):
        return self.l2(F.relu(self.l1(x)))

# %%
# Let's instantiate and test if it works
num_hidden = 128
torch.manual_seed(1234)
model = QNetwork(num_hidden)

torch.manual_seed(1234)
test_model = nn.Sequential(
    nn.Linear(4, num_hidden), 
    nn.ReLU(), 
    nn.Linear(num_hidden, 2)
)

x = torch.rand(10, 4)

# If you do not need backpropagation, wrap the computation in the torch.no_grad() context
# This saves time and memory, and PyTorch complaints when converting to numpy
with torch.no_grad():
    assert np.allclose(model(x).numpy(), test_model(x).numpy())

# %% [markdown]
# ### 1.2 Experience Replay

# %% [markdown]
# What could be a problem with doing gradient updates on a sequence of state, action pairs $((s_t, a_t), (s_{t+1}, a_{t+1}) ...)$ observed while interacting with the environment? How will using *experience replay* help to overcome this (potential problem)?

# %% [markdown]
# The problem is that successive updates in the original Q-learning approach are corralated to each other. This increases the variance in the learning and can cause instabilities.
# Experience replay can be used to solve this problem by saving an history of experiences from interacting with the environment and then learning a model by sampling experiences from this history, in order to avoid sequential updates (from Sutton and Barto, pp. 440-441).

# %% [markdown]
# Now implement the `push` function that adds a transition to the replay buffer, and the sample function that returns a batch of samples. It should keep at most the maximum number of transitions. Also implement the `sample` function that samples a (random!) batch of data, for use during training (hint: you can use the function `random.sample`).

# %%
import random
class ReplayMemory:
    
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []

    def push(self, transition):
        self.memory.append(transition)
        if len(self) == self.capacity:
            self.memory = self.memory[1:]

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
capacity = 10
memory = ReplayMemory(capacity)

# Sample a transition
s = env.reset()
a = env.action_space.sample()
s_next, r, done, _ = env.step(a)

# Push a transition
memory.push((s, a, r, s_next, done))

# Sample a batch size of 1
print(memory.sample(1))
# Out:
# [(array([-0.04301202, -0.03654786,  0.00336821,  0.00026357]), 0, 1.0, array([-0.04374298, -0.23171795,  0.00337349,  0.2940073 ]), False)]

# %% [markdown]
# ### 1.3 $\epsilon$psilon greedy policy

# %% [markdown]
# In order to learn a good policy, we need to explore quite a bit initially. As we start to learn a good policy, we want to decrease the exploration. As the amount of exploration using an $\epsilon$-greedy policy is controlled by $\epsilon$, we can define an 'exploration scheme' by writing $\epsilon$ as a function of time. There are many possible schemes, but we will use a simple one: we will start with only exploring (so taking random actions) at iteration 0, and then in 1000 iterations linearly anneal $\epsilon$ such that after 1000 iterations we take random (exploration) actions with 5\% probability (forever, as you never know if the environment will change).

# %%
def get_epsilon(it):
    return .05 if it > 1000 else (1- it * 0.95 /1000)

# %%
# So what's an easy way to check?
plt.plot([get_epsilon(it) for it in range(5000)])

# %% [markdown]
# Now write a function that takes a state and uses the Q-network to select an ($\epsilon$-greedy) action. It should return a random action with probability epsilon (which we will pass later). Note, you do not need to backpropagate through the model computations, so use `with torch.no_grad():` (see above for example). Unlike numpy, PyTorch has no argmax function, but Google is your friend... Note that to convert a PyTorch tensor with only 1 element (0 dimensional) to a simple python scalar (int or float), you can use the '.item()' function.

# %%
def select_action(model, state, epsilon):
    with torch.no_grad():
        scores = model(torch.Tensor(state))
        if random.random() > epsilon:
            m, am = scores.max(0)
            return am.item()
        return random.randint(0, scores.shape[0] - 1)

# %%
s = env.reset()
a = select_action(model, s, 0.05)
assert not torch.is_tensor(a)
print (a)
# Out:
# 1

# %% [markdown]
# ### 1.4 Training function

# %% [markdown]
# Now we will implement the function 'train' that samples a batch from the memory and performs a gradient step using some convenient PyTorch functionality. However, you still need to compute the Q-values for the (state, action) pairs in the experience, as well as their target (e.g. the value they should move towards). What is the target for a Q-learning update? What should be the target if `next_state` is terminal (e.g. `done`)?
#
# For computing the Q-values for the actions, note that the model returns all action values where you are only interested in a single action value. Because of the batch dimension, you can't use simple indexing, but you may want to have a look at [torch.gather](https://pytorch.org/docs/stable/torch.html?highlight=gather#torch.gather) or use [advanced indexing](https://docs.scipy.org/doc/numpy-1.13.0/reference/arrays.indexing.html) (numpy tutorial but works mostly the same in PyTorch). Note, you should NOT modify the function train. You can view the size of a tensor `x` with `x.size()` (similar to `x.shape` in numpy).

# %%
def compute_q_val(model, state, action):
    values = model(state)
    return torch.gather(values, 1, action.unsqueeze(-1)).reshape(-1)
    
def compute_target(model, reward, next_state, done, discount_factor):
    # done is a boolean (vector) that indicates if next_state is terminal (episode is done)
    # target = R + gamma * V(S')
    next_values = model(next_state)
    return reward + discount_factor * torch.max(next_values, 1)[0] * (1 - done.type(torch.FloatTensor)) 
    

def train(model, memory, optimizer, batch_size, discount_factor):
    # DO NOT MODIFY THIS FUNCTION
    
    # don't learn without some decent experience
    if len(memory) < batch_size:
        return None

    # random transition batch is taken from experience replay memory
    transitions = memory.sample(batch_size)
    
    # transition is a list of 4-tuples, instead we want 4 vectors (as torch.Tensor's)
    state, action, reward, next_state, done = zip(*transitions)
    
    # convert to PyTorch and define types
    state = torch.tensor(state, dtype=torch.float)
    action = torch.tensor(action, dtype=torch.int64)  # Need 64 bit to use them as index
    next_state = torch.tensor(next_state, dtype=torch.float)
    reward = torch.tensor(reward, dtype=torch.float)
    done = torch.tensor(done, dtype=torch.uint8)  # Boolean
    
    # compute the q value
    q_val = compute_q_val(model, state, action)
    
    with torch.no_grad():  # Don't compute gradient info for the target (semi-gradient)
        target = compute_target(model, reward, next_state, done, discount_factor)
    
    # loss is measured from error between current and newly expected Q values
    loss = F.smooth_l1_loss(q_val, target)

    # backpropagation of loss to Neural Network (PyTorch magic)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return loss.item()  # Returns a Python scalar, and releases history (similar to .detach())

# %%
# You may want to test your functions individually, but after you do so lets see if the method train works.
batch_size = 64
discount_factor = 0.8
learn_rate = 1e-3
# Simple gradient descent may take long, so we will use Adam
optimizer = optim.Adam(model.parameters(), learn_rate)

# We need a larger memory, fill with dummy data
transition = memory.sample(1)[0]
memory = ReplayMemory(10 * batch_size)
for i in range(batch_size):
    memory.push(transition)

# Now let's see if it works
loss = train(model, memory, optimizer, batch_size, discount_factor)

print (loss)
# Out:
# 0.5987471342086792

# %% [markdown]
# ### 1.5 Put it all together

# %% [markdown]
# Now that you have implemented the training step, you should be able to put everything together. Implement the function `run_episodes` that runs a number of episodes of DQN training. It should return the durations (e.g. number of steps) of each episode. Note: we pass the train function as an argument such that we can swap it for a different training step later.

# %%
def run_episodes(train, model, memory, env, num_episodes, batch_size, discount_factor, learn_rate):
    
    optimizer = optim.Adam(model.parameters(), learn_rate)
    
    global_steps = 0  # Count the steps (do not reset at episode start, to compute epsilon)
    episode_durations = []  #
    for i in range(num_episodes):
        s = env.reset()
        done = False
        duration = 0
        while not done:
            epsilon = get_epsilon(global_steps)
            a = select_action(model, s, epsilon)
            s_next, r, done, _ = env.step(a)
            memory.push((s, a, r, s_next, done))
            
            train(model, memory, optimizer, batch_size, discount_factor)
            
            s = s_next
            duration += 1
            global_steps += 1
            
        env.close()
        episode_durations.append(duration)
        
    return episode_durations

# %%
# Let's run it!
num_episodes = 100
batch_size = 64
discount_factor = 0.8
learn_rate = 1e-3
memory = ReplayMemory(10000)
num_hidden = 128
seed = 42  # This is not randomly chosen

# We will seed the algorithm (before initializing QNetwork!) for reproducability
random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

model = QNetwork(num_hidden)

episode_durations = run_episodes(train, model, memory, env, num_episodes, batch_size, discount_factor, learn_rate)

# %%
# And see the results
def smooth(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

plt.plot(smooth(episode_durations, 10))
plt.title('Episode durations per episode')
# Out:
# Text(0.5, 1.0, 'Episode durations per episode')

# %% [markdown]
# ### 1.6 Semi-gradient vs. true gradient (bonus)

# %% [markdown]
# Note that by using automatic differentiation in PyTorch, it is (relatively) easy to implement the true gradient method. Hint: PyTorch may complain about computing gradients for the target in [smooth_l1_loss](https://pytorch.org/docs/stable/nn.html?highlight=smooth_l1_loss#torch.nn.functional.smooth_l1_loss). How can you circumvent this problem? Implement the `train_true_gradient` method below.

# %%
def train_true_gradient(model, memory, optimizer, batch_size, discount_factor):
    
    # don't learn without some decent experience
    if len(memory) < batch_size:
        return None

    # random transition batch is taken from experience replay memory
    transitions = memory.sample(batch_size)
    
    # transition is a list of 4-tuples, instead we want 4 vectors (as torch.Tensor's)
    state, action, reward, next_state, done = zip(*transitions)
    
    # convert to PyTorch and define types
    state = torch.tensor(state, dtype=torch.float)
    action = torch.tensor(action, dtype=torch.int64)  # Need 64 bit to use them as index
    next_state = torch.tensor(next_state, dtype=torch.float)
    reward = torch.tensor(reward, dtype=torch.float)
    done = torch.tensor(done, dtype=torch.uint8)  # Boolean
    
    # compute the q value
    q_val = compute_q_val(model, state, action)
    
    # come fare in modo che il gradiente sia calcolato?
    target = compute_target(model, reward, next_state, done, discount_factor)
    
    # loss is measured from error between current and newly expected Q values
    loss = F.smooth_l1_loss(q_val - target, torch.zeros_like(q_val))

    # backpropagation of loss to Neural Network (PyTorch magic)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return loss.item()  # Returns a Python scalar, and releases history (similar to .detach())

random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

model = QNetwork(num_hidden)

episode_durations_true_gradient = run_episodes(
    train_true_gradient, model, memory, env, num_episodes, batch_size, discount_factor, learn_rate)

plt.plot(smooth(episode_durations, 10))
plt.plot(smooth(episode_durations_true_gradient, 10))
plt.title('Episode durations per episode')
plt.legend(['Semi-gradient', 'True gradient'])

# %% [markdown]
# Which algorithm performs better? Is this what you would expect? Can you explain this?
#
# Note: you may want to play around with the number of episodes to answer this question, but please reset it to 100 before handing in the notebook.

# %% [markdown]
# True gradient performs better than Semi-gradient in our case. We expect this behavior since with semi-gradient we only update the weights of our DQN based on the gradients with respect to the Q-value, but not with respect of the target values.
# Semi-gradients algorithms aim to simplify and speed up the learning of the model by ignoring the effects on the target when changing the weights of the network (update steps). However, this approximation implies that the training does not converge as robustly as True gradient does, and we can see this difference in performance when running the experiments for more episodes. In this case, we notice how both models are able to reach the maximum of 200 steps per episode after the initial steep learning phase, although True gradient fluctuates around an average of 180 steps per episode for the rest of the experiment, while Semi-gradients perform slightly worse, with an average around 160 steps per episode.

# %% [markdown]
# ---
#
# ## 2. Policy Gradient (8 points)

# %% [markdown]
# So we have spent a lot of time working on *value based* methods. We will now switch to *policy based* methods, i.e. learn a policy directly rather than learn a value function from which the policy follows. Mention two advantages of using a policy based method.

# %% [markdown]
# Some advantages of using policy based methods are:
# - we directly optimize the quantities of interest: when using approximate methods, finding the most accurate estimation of states-values does not necessarily mean we have built the best possible policy. Instead, in this case we directly improve the policy, which is what we are actually interested in
# - easier to include prior knowledge: for instance, if we already have an idea of what an optimal policy looks like, we can first train a policy to imitate our prior knowledge and then use it in a policy method
# - easier to ensure smooth changes of the policies: in value based methods, when building a new epsilon-greedy policy after each states values update, the resulting policy can be very different from the previous one. Conversely, in this case we can update directly the policy with smooth changes along the gradient

# %% [markdown]
# ### 2.1 Policy Network

# %% [markdown]
# In order to do so, we will implement a Policy network. Although in general this does not have to be the case, we will use an architecture very similar to the Q-network (two layers with ReLU activation for the hidden layer). Since we have discrete actions, our model will output one value per action, where each value represents the (normalized!) log-probability of selecting that action. *Use the (log-)softmax activation function.*

# %%
class PolicyNetwork(nn.Module):
    
    def __init__(self, num_hidden=128):
        nn.Module.__init__(self)
        self.l1 = nn.Linear(4, num_hidden)
        self.l2 = nn.Linear(num_hidden, 2)

    def forward(self, x):
        x = self.l1(x)
        x = torch.relu(x)
        x = self.l2(x)
        x = torch.nn.functional.log_softmax(x)
        return x

# %%
# Let's instantiate and test if it works
num_hidden = 128
torch.manual_seed(1234)
model = PolicyNetwork(num_hidden)

x = torch.rand(10, 4)

log_p = model(x)

# Does the outcome make sense?
print(log_p.exp())
# Out:
# tensor([[0.4578, 0.5422],
#         [0.4657, 0.5343],
#         [0.4563, 0.5437],
#         [0.4634, 0.5366],
#         [0.4564, 0.5436],
#         [0.4725, 0.5275],
#         [0.4769, 0.5231],
#         [0.4834, 0.5166],
#         [0.4797, 0.5203],
#         [0.4618, 0.5382]], grad_fn=<ExpBackward>)
# /home/gabriele/miniconda3/envs/rl2018/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   if sys.path[0] == '':

# %% [markdown]
# ### 2.2 Monte Carlo REINFORCE

# %% [markdown]
# Now we will implement the *Monte Carlo* policy gradient algorithm. Remember from lab 1 that this means that we will estimate returns for states by sample episodes. Compared to DQN, this means that we do *not* perform an update step at every environment step, but only at the end of each episode. This means that we should generate an episode of data, compute the REINFORCE loss (which requires computing the returns) and then perform a gradient step.
#
# To help you, we already implemented a few functions that you can (but do not have to) use.
#
# * You can use `torch.multinomial` to sample from a categorical distribution.
# * The REINFORCE loss is defined as $- \sum_t \log \pi_\theta(a_t|s_t) G_t$, which means that you should compute the (discounted) return $G_t$ for all $t$. Make sure that you do this in **linear time**, otherwise your algorithm will be very slow! Note the - (minus) since you want to maximize return while you want to minimize the loss.
# * Importantly, you should **normalize the returns** (not the rewards!, e.g. subtract mean and divide by standard deviation within the episode) before computing the loss, or your estimator will have very high variance.

# %%
def select_action(model, state):
    # Samples an action according to the probability distribution induced by the model
    # Also returns the log_probability
    
    log_p = model(torch.FloatTensor(state))
    
    action = torch.multinomial(torch.exp(log_p), 1).item()
    
    return action, log_p[action]

def run_episode(env, model):
    
    episode = []
    
    s = env.reset()
    done = False
    while not done:
        a, log_p = select_action(model, s)
        s_next, r, done, _ = env.step(a)
        
        episode.append((s, a, log_p, s_next, r))
        s = s_next
    
    return episode

def compute_reinforce_loss(episode, discount_factor):
    # Compute the reinforce loss
    # Make sure that your function runs in LINEAR TIME
    # Don't forget to normalize your RETURNS (not rewards)
    # Note that the rewards/returns should be maximized 
    # while the loss should be minimized so you need a - somewhere
    
    returns = []
    log_ps = []
    G = 0
    for _, _, log_p, _, r in reversed(episode):
        G = r + discount_factor * G
        returns.append(G)
        log_ps.append(log_p)
        
    log_ps = torch.stack(log_ps)
    returns = torch.FloatTensor(returns)
    returns -= returns.mean()
    returns /= returns.std()
    
    loss = -1 * torch.sum(log_ps * returns)
    return loss

def run_episodes_policy_gradient(model, env, num_episodes, discount_factor, learn_rate):
    
    optimizer = optim.Adam(model.parameters(), learn_rate)
    
    episode_durations = []
    for i in range(num_episodes):
        
        optimizer.zero_grad()
        
        episode = run_episode(env, model)
        loss = compute_reinforce_loss(episode, discount_factor)
        
        loss.backward()
        optimizer.step()
                           
        if i % 20 == 0:
            print("{2} Episode {0} finished after {1} steps"
                  .format(i, len(episode), '\033[92m' if len(episode) >= 195 else '\033[99m'))
        episode_durations.append(len(episode))
        
    return episode_durations

# %%
# Feel free to play around with the parameters!
num_episodes = 500
discount_factor = 0.99
learn_rate = 0.01
seed = 42
random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

model = PolicyNetwork(num_hidden)

episode_durations_policy_gradient = run_episodes_policy_gradient(
    model, env, num_episodes, discount_factor, learn_rate)

plt.plot(smooth(episode_durations_policy_gradient, 10))
plt.title('Episode durations per episode')
plt.legend(['Policy gradient'])
# Out:
# /home/gabriele/miniconda3/envs/rl2018/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   if sys.path[0] == '':
#  Episode 0 finished after 19 steps
#  Episode 20 finished after 27 steps
#  Episode 40 finished after 200 steps
#  Episode 60 finished after 57 steps
#  Episode 80 finished after 41 steps
#  Episode 100 finished after 200 steps
#  Episode 120 finished after 200 steps
#  Episode 140 finished after 200 steps
#  Episode 160 finished after 200 steps
#  Episode 180 finished after 105 steps
#  Episode 200 finished after 107 steps
#  Episode 220 finished after 122 steps
#  Episode 240 finished after 134 steps
#  Episode 260 finished after 200 steps
#  Episode 280 finished after 200 steps
#  Episode 300 finished after 200 steps
#  Episode 320 finished after 200 steps
#  Episode 340 finished after 98 steps
#  Episode 360 finished after 53 steps
#  Episode 380 finished after 137 steps
#  Episode 400 finished after 200 steps
#  Episode 420 finished after 200 steps
#  Episode 440 finished after 200 steps
#  Episode 460 finished after 200 steps
#  Episode 480 finished after 127 steps

# %% [markdown]
# ---
# ## Actor-Critic (7 points)

# %% [markdown]
# We will now implement the basic Actor-Critic algorithm, which means that instead of using Monte Carlo returns, we will bootstrap (1-step) returns using a critic (state-value function), so $G_t = R_t + \gamma V(s_{t+1})$. What happens at the end of the episode? Hint: you may find it useful to have a look at the `train` method for DQN.
#
# * Note that we now have to train an actor (policy) and a critic (value network).
# * We will do this using a single optimizer, which means that we have to sum the loss for the actor and the critic into a single loss term.
# * For the critic, use the `smooth_l1_loss` like with DQN.
# * For the actor, the loss should be the REINFORCE loss, but with two differences:
#     - Instead of the Monte Carlo return $G_t$, use the one step return $G_{t:t+1}$ where the critic is used to bootstrap the value of $s_{t+1}$.
#     - Instead of normalizing the returns (which can be viewed as using the average as baseline and then scaling), we will use the estimated value $V(s_t)$ as baseline.
# * **Important**: note that you cannot use `with torch.no_grad():` to compute the critic value (for the current state) since you need gradients to train the critic! However, when using the value to compute the actor loss, you do not want to get gradients of the critic parameters w.r.t. the actor loss (e.g. your target and baseline must be constant)! Therefore, use `v.detach()` on the output of the critic when it is used in the loss term for the actor, this will make sure the value(s) are treated as a constant and no gradients will be backpropagated.

# %%
class ValueNetwork(nn.Module):
    
    def __init__(self, num_hidden=128):
        nn.Module.__init__(self)
        self.l1 = nn.Linear(4, num_hidden)
        self.l2 = nn.Linear(num_hidden, 1)

    def forward(self, x):
        x = self.l1(x)
        x = torch.relu(x)
        x = self.l2(x)
        return x.view(-1)

def select_action(model, state):
    # Samples an action according to the probability distribution induced by the model
    # Also returns the log_probability
    
    log_p = model(torch.FloatTensor(state))
    
    action = torch.multinomial(torch.exp(log_p), 1)
    
    log_p = log_p.gather(1, action).view(-1)
    action = action.view(-1)
    
    # action and log_p should be a 1 dimensional vector
    n = len(state)
    assert action.size() == (n, )
    assert log_p.size() == (n, )
    return action, log_p

def train_actor_critic(actor, critic, optimizer, log_ps, state, reward, next_state, done, discount_factor):
    
    value = critic(state)
    
    # target = R + gamma * V(S')
    dones = done.type(torch.FloatTensor).view(-1)
    reward = reward.view(-1)
    next_values = critic(next_state)
    target = reward + discount_factor * next_values * (1 - dones)
    
    err = target - value
    value_loss = F.smooth_l1_loss(err, torch.zeros_like(err))
    
    # instead of "target", we use "err = target - value" since the value of the
    # current state is used as baseline
    actor_loss = -1 * (err.detach() * log_ps)
    actor_loss = actor_loss.mean() 
    
    # The loss is composed of the value_loss (for the critic) and the actor_loss
    loss = actor_loss + value_loss*0.5

    # backpropagation of loss to Neural Network (PyTorch magic)
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(actor.parameters(), 1)
    torch.nn.utils.clip_grad_norm_(critic.parameters(), 1)
    optimizer.step()
    
    return loss.item(), value_loss.item(), actor_loss.item()  # Returns a Python scalar, and releases history (similar to .detach())

def run_episodes_actor_critic(actor, critic, envs, max_episodes, max_steps, discount_factor, actor_learn_rate, critic_learn_rate):
    
    # We can use a single optimizer for both the actor and the critic, even with separate learn rates
    optimizer = optim.Adam([
        {'params': actor.parameters(), 'lr': actor_learn_rate},
        {'params': critic.parameters(), 'lr': critic_learn_rate}
    ])
    
    episode_durations = []
    state = torch.tensor([env.reset() for env in envs], dtype=torch.float)
    current_episode_lengths = torch.zeros(len(envs), dtype=torch.int64)
    step_losses = []  # Keep track of losses for plotting
    for i in range(max_steps):
        
        if i % 100 == 0:
            print(f"Step {i}, finished {len(episode_durations)} / {max_episodes} episodes, average episode duration of last 100 episodes: {np.mean(episode_durations[-100:])}")
        
        action, log_ps = select_action(actor, state)
        next_state, reward, done, _ = zip(*[env.step(a.item()) for env, a in zip(envs, action)])
        
        next_state = torch.tensor(next_state, dtype=torch.float)
        reward = torch.tensor(reward, dtype=torch.float)
        done = torch.tensor(done, dtype=torch.uint8)  # Boolean
        current_episode_lengths += 1
        
        losses = train_actor_critic(actor, critic, optimizer, log_ps, state, reward, next_state, done, discount_factor)
        
        step_losses.append(losses)
        
        # Reset envs that are done
        next_state = torch.tensor([
            env.reset() if d else s.tolist()
            for env, s, d in zip(envs, next_state, done)
        ], dtype=torch.float)
        
        episode_durations.extend(current_episode_lengths[done])
        current_episode_lengths[done] = 0  # PyTorch can also work in place
        
        state = next_state
        
        # Check if we have finished sufficiently many episodes
        if len(episode_durations) >= max_episodes:
            break
        
    return episode_durations[:max_episodes], step_losses  # In case we want exactly num_episodes returned


num_envs = 16
max_steps = 10000
max_episodes = 10000
discount_factor = 0.8
lr_actor = 5e-4
lr_critic = 5e-4
seed = 42

actor = PolicyNetwork(num_hidden)
critic = ValueNetwork(num_hidden)

envs = [gym.envs.make("CartPole-v0") for i in range(num_envs)]

for i, env in enumerate(envs):
    env.seed(seed + i)
torch.manual_seed(seed)

episode_durations, step_losses = run_episodes_actor_critic(actor, critic, envs, max_episodes, max_steps, discount_factor, lr_actor, lr_critic)
# Out:
# Step 0, finished 0 / 10000 episodes, average episode duration of last 100 episodes: nan
# Step 100, finished 82 / 10000 episodes, average episode duration of last 100 episodes: 18.01219512195122
# /home/davide/miniconda3/envs/rl2018/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   if sys.path[0] == '':
# Step 200, finished 178 / 10000 episodes, average episode duration of last 100 episodes: 16.59
# Step 300, finished 273 / 10000 episodes, average episode duration of last 100 episodes: 17.42
# Step 400, finished 353 / 10000 episodes, average episode duration of last 100 episodes: 18.91
# Step 500, finished 401 / 10000 episodes, average episode duration of last 100 episodes: 24.83
# Step 600, finished 444 / 10000 episodes, average episode duration of last 100 episodes: 33.29
# Step 700, finished 478 / 10000 episodes, average episode duration of last 100 episodes: 37.95
# Step 800, finished 509 / 10000 episodes, average episode duration of last 100 episodes: 43.04
# Step 900, finished 542 / 10000 episodes, average episode duration of last 100 episodes: 46.68
# Step 1000, finished 571 / 10000 episodes, average episode duration of last 100 episodes: 50.91
# Step 1100, finished 596 / 10000 episodes, average episode duration of last 100 episodes: 53.57
# Step 1200, finished 619 / 10000 episodes, average episode duration of last 100 episodes: 55.54
# Step 1300, finished 638 / 10000 episodes, average episode duration of last 100 episodes: 62.53
# Step 1400, finished 661 / 10000 episodes, average episode duration of last 100 episodes: 68.16
# Step 1500, finished 687 / 10000 episodes, average episode duration of last 100 episodes: 69.94
# Step 1600, finished 706 / 10000 episodes, average episode duration of last 100 episodes: 72.47
# Step 1700, finished 722 / 10000 episodes, average episode duration of last 100 episodes: 76.07
# Step 1800, finished 738 / 10000 episodes, average episode duration of last 100 episodes: 78.31
# Step 1900, finished 755 / 10000 episodes, average episode duration of last 100 episodes: 81.51
# Step 2000, finished 769 / 10000 episodes, average episode duration of last 100 episodes: 86.62
# Step 2100, finished 790 / 10000 episodes, average episode duration of last 100 episodes: 93.1
# Step 2200, finished 802 / 10000 episodes, average episode duration of last 100 episodes: 95.53
# Step 2300, finished 814 / 10000 episodes, average episode duration of last 100 episodes: 101.65
# Step 2400, finished 825 / 10000 episodes, average episode duration of last 100 episodes: 105.92
# Step 2500, finished 837 / 10000 episodes, average episode duration of last 100 episodes: 109.59
# Step 2600, finished 846 / 10000 episodes, average episode duration of last 100 episodes: 115.58
# Step 2700, finished 856 / 10000 episodes, average episode duration of last 100 episodes: 122.27
# Step 2800, finished 863 / 10000 episodes, average episode duration of last 100 episodes: 126.79
# Step 2900, finished 876 / 10000 episodes, average episode duration of last 100 episodes: 135.77
# Step 3000, finished 891 / 10000 episodes, average episode duration of last 100 episodes: 141.99
# Step 3100, finished 897 / 10000 episodes, average episode duration of last 100 episodes: 145.92
# Step 3200, finished 908 / 10000 episodes, average episode duration of last 100 episodes: 152.68
# Step 3300, finished 918 / 10000 episodes, average episode duration of last 100 episodes: 154.14
# Step 3400, finished 926 / 10000 episodes, average episode duration of last 100 episodes: 156.63
# Step 3500, finished 937 / 10000 episodes, average episode duration of last 100 episodes: 160.39
# Step 3600, finished 946 / 10000 episodes, average episode duration of last 100 episodes: 161.89
# Step 3700, finished 955 / 10000 episodes, average episode duration of last 100 episodes: 162.85
# Step 3800, finished 964 / 10000 episodes, average episode duration of last 100 episodes: 162.27
# Step 3900, finished 971 / 10000 episodes, average episode duration of last 100 episodes: 163.45
# Step 4000, finished 981 / 10000 episodes, average episode duration of last 100 episodes: 169.25
# Step 4100, finished 992 / 10000 episodes, average episode duration of last 100 episodes: 171.71
# Step 4200, finished 1000 / 10000 episodes, average episode duration of last 100 episodes: 172.27
# Step 4300, finished 1011 / 10000 episodes, average episode duration of last 100 episodes: 169.6
# Step 4400, finished 1017 / 10000 episodes, average episode duration of last 100 episodes: 171.84
# Step 4500, finished 1029 / 10000 episodes, average episode duration of last 100 episodes: 173.52
# Step 4600, finished 1033 / 10000 episodes, average episode duration of last 100 episodes: 175.47
# Step 4700, finished 1045 / 10000 episodes, average episode duration of last 100 episodes: 178.36
# Step 4800, finished 1049 / 10000 episodes, average episode duration of last 100 episodes: 178.55
# Step 4900, finished 1063 / 10000 episodes, average episode duration of last 100 episodes: 179.99
# Step 5000, finished 1071 / 10000 episodes, average episode duration of last 100 episodes: 176.31
# Step 5100, finished 1080 / 10000 episodes, average episode duration of last 100 episodes: 175.39
# Step 5200, finished 1095 / 10000 episodes, average episode duration of last 100 episodes: 177.19
# Step 5300, finished 1099 / 10000 episodes, average episode duration of last 100 episodes: 175.33
# Step 5400, finished 1112 / 10000 episodes, average episode duration of last 100 episodes: 176.99
# Step 5500, finished 1116 / 10000 episodes, average episode duration of last 100 episodes: 176.53
# Step 5600, finished 1130 / 10000 episodes, average episode duration of last 100 episodes: 175.66
# Step 5700, finished 1132 / 10000 episodes, average episode duration of last 100 episodes: 175.66
# Step 5800, finished 1146 / 10000 episodes, average episode duration of last 100 episodes: 175.62
# Step 5900, finished 1149 / 10000 episodes, average episode duration of last 100 episodes: 174.98
# Step 6000, finished 1162 / 10000 episodes, average episode duration of last 100 episodes: 176.77
# Step 6100, finished 1165 / 10000 episodes, average episode duration of last 100 episodes: 177.54
# Step 6200, finished 1178 / 10000 episodes, average episode duration of last 100 episodes: 183.74
# Step 6300, finished 1181 / 10000 episodes, average episode duration of last 100 episodes: 184.51
# Step 6400, finished 1194 / 10000 episodes, average episode duration of last 100 episodes: 188.06
# Step 6500, finished 1197 / 10000 episodes, average episode duration of last 100 episodes: 188.67
# Step 6600, finished 1210 / 10000 episodes, average episode duration of last 100 episodes: 193.58
# Step 6700, finished 1215 / 10000 episodes, average episode duration of last 100 episodes: 192.82
# Step 6800, finished 1229 / 10000 episodes, average episode duration of last 100 episodes: 194.3
# Step 6900, finished 1239 / 10000 episodes, average episode duration of last 100 episodes: 189.38
# Step 7000, finished 1245 / 10000 episodes, average episode duration of last 100 episodes: 188.15
# Step 7100, finished 1256 / 10000 episodes, average episode duration of last 100 episodes: 187.8
# Step 7200, finished 1261 / 10000 episodes, average episode duration of last 100 episodes: 187.72
# Step 7300, finished 1272 / 10000 episodes, average episode duration of last 100 episodes: 187.16
# Step 7400, finished 1277 / 10000 episodes, average episode duration of last 100 episodes: 187.02
# Step 7500, finished 1288 / 10000 episodes, average episode duration of last 100 episodes: 186.51
# Step 7600, finished 1293 / 10000 episodes, average episode duration of last 100 episodes: 186.71
# Step 7700, finished 1304 / 10000 episodes, average episode duration of last 100 episodes: 187.55
# Step 7800, finished 1309 / 10000 episodes, average episode duration of last 100 episodes: 187.63
# Step 7900, finished 1320 / 10000 episodes, average episode duration of last 100 episodes: 188.68
# Step 8000, finished 1325 / 10000 episodes, average episode duration of last 100 episodes: 188.69
# Step 8100, finished 1336 / 10000 episodes, average episode duration of last 100 episodes: 194.73
# Step 8200, finished 1343 / 10000 episodes, average episode duration of last 100 episodes: 195.69
# Step 8300, finished 1353 / 10000 episodes, average episode duration of last 100 episodes: 195.24
# Step 8400, finished 1361 / 10000 episodes, average episode duration of last 100 episodes: 194.1
# Step 8500, finished 1369 / 10000 episodes, average episode duration of last 100 episodes: 194.12
# Step 8600, finished 1378 / 10000 episodes, average episode duration of last 100 episodes: 193.51
# Step 8700, finished 1386 / 10000 episodes, average episode duration of last 100 episodes: 193.29
# Step 8800, finished 1394 / 10000 episodes, average episode duration of last 100 episodes: 193.24
# Step 8900, finished 1402 / 10000 episodes, average episode duration of last 100 episodes: 193.24
# Step 9000, finished 1411 / 10000 episodes, average episode duration of last 100 episodes: 192.56
# Step 9100, finished 1418 / 10000 episodes, average episode duration of last 100 episodes: 191.8
# Step 9200, finished 1428 / 10000 episodes, average episode duration of last 100 episodes: 191.23
# Step 9300, finished 1437 / 10000 episodes, average episode duration of last 100 episodes: 188.48
# Step 9400, finished 1448 / 10000 episodes, average episode duration of last 100 episodes: 186.98
# Step 9500, finished 1454 / 10000 episodes, average episode duration of last 100 episodes: 186.32
# Step 9600, finished 1465 / 10000 episodes, average episode duration of last 100 episodes: 187.34
# Step 9700, finished 1472 / 10000 episodes, average episode duration of last 100 episodes: 187.36
# Step 9800, finished 1482 / 10000 episodes, average episode duration of last 100 episodes: 187.31
# Step 9900, finished 1488 / 10000 episodes, average episode duration of last 100 episodes: 187.94

# %%
plt.plot(smooth(episode_durations, 100))
plt.title('Episode durations')
plt.show()
loss, v_loss, a_loss = zip(*step_losses)

plt.plot(smooth(v_loss, 100))
plt.title('Value loss')
plt.show()
plt.plot(smooth(a_loss, 100))
plt.title('Actor loss')
plt.show()

# %% [markdown]
# What is the difficulty of training AC algorithms? What could you try to do to overcome these difficulties? Hint: look at some online implementations.

# %% [markdown]
# The main problem in training AC algorithms comes from the correlation between the actor and critic networks. Indeed, since the signal from the critic is used to improve the actor, a meaningful signal is necessary for our actor network to learn a good policy. This could not be the case especially in earlier stages of the training, when both networks' weights are still mostly random. To circumvent this issue, we can use techniques analogue to the ones used to balance generator and discriminator networks in GANs. For example, one idea is to start training the critic network first so that it can better match the actual rewards when describing the value function. After some iterations, we can start training the actor network as well, so that the signal from the critic network is more likely to be meaningful.

# %% [markdown]
# ## Deep Reinforcement Learning (5 bonus points)
# Note that so far we used the state variables as input. However, the true power of Deep Learning is that we can directly learn from raw inputs, e.g. we can learn to balance the cart pole *by just looking at the screen*. This probably means that you need a deep(er) (convolutional) network, as well as tweaking some parameters, running for more iterations (perhaps on GPU) and do other tricks to stabilize learning. Can you get this to work? This will earn you bonus points!
#
# Hints:
# * You may want to use [Google Colab](https://colab.research.google.com/) such that you can benefit from GPU acceleration.
# * Even if you don't use Colab, save the weights of your final model and load it in the code here (see example below). Hand in the model file with the .ipynb in a .zip. We likely won't be able to run your training code during grading!
# * To run the code below, you need to install `torchvision`, for this uncomment the two lines in the cell below or run the command in a terminal. Note: you may need to restart the terminal after installing.
# * Preprocessing is already done for you, and the observation is the difference between two consequtive frames such that the model can 'see' (angular) speed from a single image. Now do you see why we (sometimes) use the word observation (and not state)?

# %%
# %%bash
# conda install torchvision -c pytorch

# %%
import torchvision.transforms as T
from PIL import Image


resize = T.Compose([T.ToPILImage(),
                    T.Resize(40, interpolation=Image.CUBIC),
                    T.ToTensor()])

class CartPoleRawEnv(gym.Env):
    
    def __init__(self, *args, **kwargs):
        self._env = gym.make('CartPole-v0', *args, **kwargs)  #.unwrapped
        self.action_space = self._env.action_space
        screen_height, screen_width = 40, 80  # TODO
        self.observation_space = gym.spaces.Box(
            low=0, high=255, 
            shape=(screen_height, screen_width, 3), dtype=np.uint8)
    
    def seed(self, seed=None):
        return self._env.seed(seed)
    
    def reset(self):
        s = self._env.reset()
        self.prev_screen = self.screen = self.get_screen()
        return self._get_observation()
    
    def step(self, action):
        s, r, done, info = self._env.step(action)
        self.prev_screen = self.screen
        self.screen = self.get_screen()
        return self._get_observation(), r, done, info
    
    def _get_observation(self):
        return self.screen - self.prev_screen
    
    def _get_cart_location(self, screen_width):
        _env = self._env.unwrapped
        world_width = _env.x_threshold * 2
        scale = screen_width / world_width
        return int(_env.state[0] * scale + screen_width / 2.0)  # MIDDLE OF CART

    def get_screen(self):
        screen = self._env.unwrapped.render(mode='rgb_array').transpose(
            (2, 0, 1))  # transpose into torch order (CHW)
        # Strip off the top and bottom of the screen
        _, screen_height, screen_width = screen.shape
        screen = screen[:, screen_height * 4 // 10:screen_height * 8 // 10]
        view_width = screen_height * 8 // 10
        cart_location = self._get_cart_location(screen_width)
        if cart_location < view_width // 2:
            slice_range = slice(view_width)
        elif cart_location > (screen_width - view_width // 2):
            slice_range = slice(-view_width, None)
        else:
            slice_range = slice(cart_location - view_width // 2,
                                cart_location + view_width // 2)
        # Strip off the edges, so that we have a square image centered on a cart
        screen = screen[:, :, slice_range]
        # Convert to float, rescare, convert to torch tensor
        # (this doesn't require a copy)
        screen = np.ascontiguousarray(screen, dtype=np.float32) / 255
        screen = torch.from_numpy(screen)
        # Resize, and add a batch dimension (BCHW)
        #return screen.unsqueeze(0).to(device)
        return resize(screen).unsqueeze(0)
    
    def close(self):
        return self._env.close()

raw_env = CartPoleRawEnv()
s = raw_env.reset()

# 
s, r, done, _ = raw_env.step(env.action_space.sample())

raw_env.reset()
plt.figure()
plt.imshow(raw_env.get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
plt.show()

# Observations are (-1, 1) while we need to plot (0, 1) so show (rgb + 1) / 2
plt.figure()
plt.imshow((s.cpu().squeeze(0).permute(1, 2, 0).numpy() + 1) / 2,
           interpolation='none')
plt.title('Example observation')
plt.show()
raw_env.close()

# %% [markdown]
# # Deep RL with REINFORCE

# %%
def select_action(model, state):
    log_p = model(state.to(device=device))
    p = torch.exp(log_p)
    action = torch.multinomial(p, 1).item()
    log_p = log_p[0, action]
    return action, log_p

def run_episode(env, model):
    
    episode = []
    
    s = env.reset()
    done = False
    while not done:
        a, log_p = select_action(model, s)
        s_next, r, done, _ = env.step(a)
        
        episode.append((s, a, log_p, s_next, r))
        s = s_next
    
    return episode

def compute_reinforce_loss(episode, discount_factor):
    
    returns = []
    log_ps = []
    G = 0
    for _, _, log_p, _, r in reversed(episode):
        G = r + discount_factor * G
        returns.append(G)
        log_ps.append(log_p)
        
    log_ps = torch.stack(log_ps).to(device=device)
    returns = torch.FloatTensor(returns).to(device=device)
    returns -= returns.mean()
    returns /= returns.std()
    
    loss = -1 * torch.sum(log_ps * returns)
    return loss

def run_episodes_policy_gradient(model, env, num_episodes, discount_factor, learn_rate):
    
    optimizer = optim.Adam(model.parameters(), learn_rate)
    
    episode_durations = []
    for i in range(num_episodes):
        
        episode = run_episode(env, model)
        loss = compute_reinforce_loss(episode, discount_factor)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                           
        if i % 5 == 0:
            print("{2} Episode {0} finished after {1} steps"
                  .format(i, len(episode), '\033[92m' if len(episode) >= 195 else '\033[99m'))
        episode_durations.append(len(episode))
        
    return episode_durations

# Maybe you should make it a bit deeper?
class DeepPolicy(nn.Module):
    def __init__(self):
        nn.Module.__init__(self)
        self.cl1 = nn.Conv2d(3, 32, 5, padding=0)#, stride=2)
        self.pl1 = nn.MaxPool2d(2)
#         self.bn1 = nn.BatchNorm2d(16)
        
        self.cl2 = nn.Conv2d(32, 64, 3, padding=0)#, stride=2)
        self.pl2 = nn.MaxPool2d(2)
#         self.bn2 = nn.BatchNorm2d(32)
        
        self.cl3 = nn.Conv2d(64, 128, 3, padding=0)
        self.pl3 = nn.MaxPool2d(2)
#         self.bn3 = nn.BatchNorm2d(32)

        self.cl4 = nn.Conv2d(128, 128, 3, padding=0)
        
#         self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.l1 = nn.Linear(6*128, 64)
#         self.l1 = nn.Linear(256, 32)
        self.l2 = nn.Linear(64, 2)

    def forward(self, x):
        # Flatten
        x = self.cl1(x)
        x = self.pl1(x)
#         x = self.bn1(x)
        x = torch.relu(x)
        
        x = self.cl2(x)
        x = self.pl2(x)
#         x = self.bn2(x)
        x = torch.relu(x)
        
        x = self.cl3(x)
        x = self.pl3(x)
#         x = self.bn3(x)
        x = torch.relu(x)
    
        x = self.cl4(x)
        
#         x = self.ap(x)
        x = x.view(x.size(0), -1)
        
        x = self.l1(x)
        x = torch.relu(x)
        x = self.l2(x)
    
        return F.log_softmax(x, -1)
        
print("CUDA:", torch.cuda.is_available())
device = "cuda:0" if torch.cuda.is_available() else "cpu"
policy = DeepPolicy().to(device=device)
print(next(policy.parameters()).is_cuda)
filename = 'weights_reinforce.pt'

if os.path.isfile(filename):
    print(f"Loading weights from {filename}")
    weights = torch.load(filename)
    
    policy.load_state_dict(weights['policy'])
    
else:
    # Train
    
    learn_rate = 1e-4
    discount_factor = 0.99
    num_episodes = 1000
    seed = 42

    env = CartPoleRawEnv()
    
    env.seed(seed)
    torch.manual_seed(seed)
    
    try:
        episode_durations = run_episodes_policy_gradient(policy, env, num_episodes, discount_factor, learn_rate)
    except KeyboardInterrupt as err:
        env.close()
        raise err
    
    plt.plot(smooth(episode_durations, 20))
    plt.title('Episode durations')
    plt.show()
        
    print(f"Saving weights to {filename}")
    torch.save({
        # You can add more here if you need, e.g. critic
        'policy': policy.state_dict(),  # Always save weights rather than objects
    },
    filename)
    
#     plot_trends(episode_durations, step_losses)
    

def bonus_get_action(x):
    return policy(x.to(device=device)).exp().multinomial(1)[:, 0]
# Out:
# CUDA: True
# True
#  Episode 0 finished after 23 steps
#  Episode 5 finished after 10 steps
#  Episode 10 finished after 11 steps
#  Episode 15 finished after 14 steps
#  Episode 20 finished after 23 steps
#  Episode 25 finished after 8 steps
#  Episode 30 finished after 14 steps
#  Episode 35 finished after 16 steps
#  Episode 40 finished after 20 steps
#  Episode 45 finished after 15 steps
#  Episode 50 finished after 19 steps
#  Episode 55 finished after 12 steps
#  Episode 60 finished after 32 steps
#  Episode 65 finished after 35 steps
#  Episode 70 finished after 55 steps
#  Episode 75 finished after 13 steps
#  Episode 80 finished after 18 steps
#  Episode 85 finished after 15 steps
#  Episode 90 finished after 15 steps
#  Episode 95 finished after 18 steps
#  Episode 100 finished after 16 steps
#  Episode 105 finished after 10 steps
#  Episode 110 finished after 46 steps
#  Episode 115 finished after 30 steps
#  Episode 120 finished after 16 steps
#  Episode 125 finished after 11 steps
#  Episode 130 finished after 19 steps
#  Episode 135 finished after 17 steps
#  Episode 140 finished after 15 steps
#  Episode 145 finished after 10 steps
#  Episode 150 finished after 47 steps
#  Episode 155 finished after 27 steps
#  Episode 160 finished after 13 steps
#  Episode 165 finished after 26 steps
#  Episode 170 finished after 25 steps
#  Episode 175 finished after 28 steps
#  Episode 180 finished after 20 steps
#  Episode 185 finished after 23 steps
#  Episode 190 finished after 20 steps
#  Episode 195 finished after 31 steps
#  Episode 200 finished after 20 steps
#  Episode 205 finished after 11 steps
#  Episode 210 finished after 54 steps
#  Episode 215 finished after 13 steps
#  Episode 220 finished after 22 steps
#  Episode 225 finished after 19 steps
#  Episode 230 finished after 33 steps
#  Episode 235 finished after 13 steps
#  Episode 240 finished after 11 steps
#  Episode 245 finished after 40 steps
#  Episode 250 finished after 10 steps
#  Episode 255 finished after 13 steps
#  Episode 260 finished after 68 steps
#  Episode 265 finished after 66 steps
#  Episode 270 finished after 18 steps
#  Episode 275 finished after 16 steps
#  Episode 280 finished after 61 steps
#  Episode 285 finished after 23 steps
#  Episode 290 finished after 20 steps
#  Episode 295 finished after 30 steps
#  Episode 300 finished after 31 steps
#  Episode 305 finished after 21 steps
#  Episode 310 finished after 12 steps
#  Episode 315 finished after 18 steps
#  Episode 320 finished after 28 steps
#  Episode 325 finished after 13 steps
#  Episode 330 finished after 28 steps
#  Episode 335 finished after 48 steps
#  Episode 340 finished after 22 steps
#  Episode 345 finished after 20 steps
#  Episode 350 finished after 12 steps
#  Episode 355 finished after 32 steps
#  Episode 360 finished after 16 steps
#  Episode 365 finished after 27 steps
#  Episode 370 finished after 18 steps
#  Episode 375 finished after 42 steps
#  Episode 380 finished after 16 steps
#  Episode 385 finished after 21 steps
#  Episode 390 finished after 25 steps
#  Episode 395 finished after 27 steps
#  Episode 400 finished after 10 steps
#  Episode 405 finished after 25 steps
#  Episode 410 finished after 22 steps
#  Episode 415 finished after 14 steps
#  Episode 420 finished after 51 steps
#  Episode 425 finished after 16 steps
#  Episode 430 finished after 26 steps
#  Episode 435 finished after 18 steps
#  Episode 440 finished after 41 steps
#  Episode 445 finished after 15 steps
#  Episode 450 finished after 48 steps
#  Episode 455 finished after 14 steps
#  Episode 460 finished after 52 steps
#  Episode 465 finished after 8 steps
#  Episode 470 finished after 16 steps
#  Episode 475 finished after 18 steps
#  Episode 480 finished after 19 steps
#  Episode 485 finished after 48 steps
#  Episode 490 finished after 35 steps
#  Episode 495 finished after 17 steps
#  Episode 500 finished after 29 steps
#  Episode 505 finished after 49 steps
#  Episode 510 finished after 23 steps
#  Episode 515 finished after 18 steps
#  Episode 520 finished after 59 steps
#  Episode 525 finished after 15 steps
#  Episode 530 finished after 18 steps
#  Episode 535 finished after 11 steps
#  Episode 540 finished after 22 steps
#  Episode 545 finished after 12 steps
#  Episode 550 finished after 20 steps
#  Episode 555 finished after 93 steps
#  Episode 560 finished after 11 steps
#  Episode 565 finished after 74 steps
#  Episode 570 finished after 35 steps
#  Episode 575 finished after 19 steps
#  Episode 580 finished after 14 steps
#  Episode 585 finished after 23 steps
#  Episode 590 finished after 13 steps
#  Episode 595 finished after 16 steps
#  Episode 600 finished after 18 steps
#  Episode 605 finished after 12 steps
#  Episode 610 finished after 23 steps
#  Episode 615 finished after 24 steps
#  Episode 620 finished after 22 steps
#  Episode 625 finished after 15 steps
#  Episode 630 finished after 102 steps
#  Episode 635 finished after 12 steps
#  Episode 640 finished after 24 steps
#  Episode 645 finished after 19 steps
#  Episode 650 finished after 39 steps
#  Episode 655 finished after 34 steps
#  Episode 660 finished after 39 steps
#  Episode 665 finished after 15 steps
#  Episode 670 finished after 33 steps
#  Episode 675 finished after 133 steps
#  Episode 680 finished after 37 steps
#  Episode 685 finished after 150 steps
#  Episode 690 finished after 200 steps
#  Episode 695 finished after 37 steps
#  Episode 700 finished after 112 steps
#  Episode 705 finished after 115 steps
#  Episode 710 finished after 135 steps
#  Episode 715 finished after 123 steps
#  Episode 720 finished after 109 steps
#  Episode 725 finished after 193 steps
#  Episode 730 finished after 200 steps
#  Episode 735 finished after 200 steps
#  Episode 740 finished after 190 steps
#  Episode 745 finished after 200 steps
#  Episode 750 finished after 178 steps
#  Episode 755 finished after 200 steps
#  Episode 760 finished after 164 steps
#  Episode 765 finished after 170 steps
#  Episode 770 finished after 192 steps
#  Episode 775 finished after 151 steps
#  Episode 780 finished after 200 steps
#  Episode 785 finished after 193 steps
#  Episode 790 finished after 200 steps
#  Episode 795 finished after 200 steps
#  Episode 800 finished after 135 steps
#  Episode 805 finished after 152 steps
#  Episode 810 finished after 114 steps
#  Episode 815 finished after 89 steps
#  Episode 820 finished after 118 steps
#  Episode 825 finished after 67 steps
#  Episode 830 finished after 92 steps
#  Episode 835 finished after 105 steps
#  Episode 840 finished after 128 steps
#  Episode 845 finished after 111 steps
#  Episode 850 finished after 103 steps
#  Episode 855 finished after 200 steps
#  Episode 860 finished after 200 steps
#  Episode 865 finished after 118 steps
#  Episode 870 finished after 161 steps
#  Episode 875 finished after 200 steps
#  Episode 880 finished after 162 steps
#  Episode 885 finished after 200 steps
#  Episode 890 finished after 155 steps
#  Episode 895 finished after 146 steps
#  Episode 900 finished after 175 steps
#  Episode 905 finished after 200 steps
#  Episode 910 finished after 189 steps
#  Episode 915 finished after 200 steps
#  Episode 920 finished after 200 steps
#  Episode 925 finished after 182 steps
#  Episode 930 finished after 200 steps
#  Episode 935 finished after 131 steps
#  Episode 940 finished after 200 steps
#  Episode 945 finished after 200 steps
#  Episode 950 finished after 174 steps
#  Episode 955 finished after 200 steps
#  Episode 960 finished after 104 steps
#  Episode 965 finished after 151 steps
#  Episode 970 finished after 148 steps
#  Episode 975 finished after 119 steps
#  Episode 980 finished after 200 steps
#  Episode 985 finished after 157 steps
#  Episode 990 finished after 136 steps
#  Episode 995 finished after 163 steps
# Saving weights to weights.pt

# %%
for e in envs:
    e.close()

# %% [markdown]
# ## Let's simulate 20 episodes with the trained model

# %%
seed = 42
episode_durations = []
for i in range(20):  # Not too many since it may take forever to render
    test_env = CartPoleRawEnv()
    test_env.seed(seed + i)
    state = test_env.reset()
    done = False
    steps = 0
    while not done:
        steps += 1
        with torch.no_grad():
            action = bonus_get_action(state).item()
        state, reward, done, _ = test_env.step(action)
    episode_durations.append(steps)
    test_env.close()
    
plt.plot(smooth(episode_durations, 10))
plt.title('Episode durations')
plt.show()

# %% [markdown]
# # Deep RL with Actor-Critic Model
#
# (this does not really learn. Still, we implemented it and tried to tune it for more than a while)

# %%
class QueueReplayMemory:
    
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []

    def push(self, transition):
        if len(self) >= self.capacity:
            self.memory.pop(0)
        self.memory.append(transition)

    def sample(self, batch_size):
        if batch_size > len(self):
            return None
        
        s, a, r, t, d = zip(*random.sample(self.memory, batch_size))
        
#         print(len(s), len(a), len(r), len(t), len(d))
        
        s = torch.cat(s)
        t = torch.cat(t)
        
        r = torch.tensor(r, dtype=torch.float)
        d = torch.tensor(d, dtype=torch.float)
        a = torch.stack(a)
        
#         print(s.shape, a.shape, r.shape, t.shape, d.shape)
        
#         assert s.shape == (batch_size, 3, 40, 80)
#         assert t.shape == (batch_size, 3, 40, 80)
#         assert r.shape == (batch_size,)
#         assert d.shape == (batch_size,)
#         assert a.shape == (batch_size,)
        
        return s, a, r, t, d

    def __len__(self):
        return len(self.memory)


def select_action(model, state):
    log_p = model(state)
    p = torch.exp(log_p).to(device=device)
#     print(p.mean(0), p.var(dim=0))
    action = torch.multinomial(p, 1)
#     print(p[:, 0].data.view(-1), action.view(-1))
    log_p = log_p.gather(1, action).view(-1)
    action = action.view(-1)
#     n = len(state)
#     assert action.size() == (n, )
#     assert log_p.size() == (n, )
    return action, log_p

def train_actor_critic(actor, critic, memory, optimizer, log_ps, state, reward, next_state, done, discount_factor):
    
    batch = memory.sample(32)
    
    if batch is None or len(memory) < 128:
        return 0, 0, 0
    
    state, action, reward, next_state, done = batch
    
    value = critic(state)
    
    # target = R + gamma * V(S')
    dones = done.type(torch.FloatTensor).to(device=device).reshape(-1)
    reward = reward.reshape(-1).to(device=device)
    next_values = critic(next_state.to(device=device))
    target = reward + discount_factor * next_values * (1 - dones)
    
    adv = target - value
    value_loss = F.smooth_l1_loss(adv, torch.zeros_like(adv).to(device=device))
    
    log_ps = actor(state).gather(1, action.view(-1, 1)).view(-1)
    actor_loss = -1 * (adv.detach() * log_ps).mean()
    
    # The loss is composed of the value_loss (for the critic) and the actor_loss
    loss = value_loss + actor_loss * 0.5

    # backpropagation of loss to Neural Network (PyTorch magic)
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(actor.parameters(), 0.5)
    torch.nn.utils.clip_grad_norm_(critic.parameters(), 0.5)
#     print(
#         sum([torch.sum(x.grad.data**2).item() for x in actor.parameters()]),
#         sum([torch.sum(x.grad.data**2).item() for x in critic.parameters()])
#     )
    optimizer.step()
    
    return loss.item(), value_loss.item(), actor_loss.item()  # Returns a Python scalar, and releases history (similar to .detach())

def run_episodes_actor_critic(actor, critic, envs, max_episodes, max_steps, discount_factor, actor_learn_rate, critic_learn_rate):
    
    # We can use a single optimizer for both the actor and the critic, even with separate learn rates
    optimizer = optim.Adam([
        {'params': actor.parameters(), 'lr': actor_learn_rate},
        {'params': critic.parameters(), 'lr': critic_learn_rate}
    ])
    
    episode_durations = []
    state = torch.cat([env.reset() for env in envs]).to(device=device)
    current_episode_lengths = torch.zeros(len(envs), dtype=torch.int64).to(device=device)
    step_losses = []  # Keep track of losses for plotting
    
    memory = QueueReplayMemory(1000)
    
    LOG = 30
    
    for i in range(max_steps):

        if i % LOG == 0 and i > 0:
            print(f"Step {i}, finished {len(episode_durations)} / {max_episodes} episodes. Last {LOG} episodes:")
            print(f"\t\t\tavg episode duration: {np.mean(episode_durations[-LOG:])}")
            print(f"\t\t\tmax episode duration: {max(episode_durations[-LOG:])}")

        action, log_ps = select_action(actor, state)
        next_state, reward, done, _ = zip(*[env.step(a.item()) for env, a in zip(envs, action)])
        
        for t in zip(state.split(1, dim=0), action, reward, next_state, done):
            memory.push(t)
        
        next_state = torch.cat(next_state).to(device=device)
        reward = torch.tensor(reward, dtype=torch.float).to(device=device)
        done = torch.tensor(done, dtype=torch.uint8).to(device=device)  # Boolean
        current_episode_lengths += 1

        losses = train_actor_critic(actor, critic, memory, optimizer, log_ps, state, reward, next_state, done, discount_factor)

        step_losses.append(losses)

        if i % LOG == 0 and i > 0:
            last_losses = step_losses[-LOG:]
            t_loss = np.mean([l for l, _, _  in last_losses])
            c_loss = np.mean([c for _, c, _  in last_losses])
            a_loss = np.mean([a for _, _, a  in last_losses])
            print(f"\t\tAvg Loss. Total: {t_loss}; Actor: {a_loss}; Critic: {c_loss}")

        episode_durations.extend(current_episode_lengths[done])
        current_episode_lengths[done] = 0  # PyTorch can also work in place
        
        # Reset envs that are done
        next_state = [
            env.reset().to(device=device) if d else s
            for env, s, d in zip(envs, next_state.split(1, dim=0), done)
        ]
        next_state = torch.cat(next_state)
        state = next_state

        # Check if we have finished sufficiently many episodes
        if len(episode_durations) >= max_episodes:
            break
    
    return episode_durations[:max_episodes], step_losses  # In case we want exactly num_episodes returned


# Maybe you should make it a bit deeper?
class DeepPolicy(nn.Module):
    def __init__(self):
        nn.Module.__init__(self)
        self.cl1 = nn.Conv2d(3, 32, 5, padding=0)#, stride=2)
        self.pl1 = nn.MaxPool2d(2)
#         self.bn1 = nn.BatchNorm2d(16)
        
        self.cl2 = nn.Conv2d(32, 64, 3, padding=0)#, stride=2)
        self.pl2 = nn.MaxPool2d(2)
#         self.bn2 = nn.BatchNorm2d(32)
        
        self.cl3 = nn.Conv2d(64, 128, 3, padding=0)
        self.pl3 = nn.MaxPool2d(2)
#         self.bn3 = nn.BatchNorm2d(32)

        self.cl4 = nn.Conv2d(128, 128, 3, padding=0)
        
#         self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.l1 = nn.Linear(6*128, 64)
#         self.l1 = nn.Linear(256, 32)
        self.l2 = nn.Linear(64, 2)

    def forward(self, x):
        # Flatten
        x = self.cl1(x)
        x = self.pl1(x)
#         x = self.bn1(x)
        x = torch.relu(x)
        
        x = self.cl2(x)
        x = self.pl2(x)
#         x = self.bn2(x)
        x = torch.relu(x)
        
        x = self.cl3(x)
        x = self.pl3(x)
#         x = self.bn3(x)
        x = torch.relu(x)
    
        x = self.cl4(x)
        x = torch.relu(x)
#         x = self.ap(x)
        x = x.view(x.size(0), -1)
        
        x = self.l1(x)
        x = torch.relu(x)
        x = self.l2(x)
    
        return F.log_softmax(x, -1)

class DeepCritic(nn.Module):
    def __init__(self):
        nn.Module.__init__(self)
        self.cl1 = nn.Conv2d(3, 32, 5, padding=0)#, stride=2)
        self.pl1 = nn.MaxPool2d(2)
#         self.bn1 = nn.BatchNorm2d(16)
        
        self.cl2 = nn.Conv2d(32, 64, 3, padding=0)#, stride=2)
        self.pl2 = nn.MaxPool2d(2)
#         self.bn2 = nn.BatchNorm2d(32)
        
        self.cl3 = nn.Conv2d(64, 128, 3, padding=0)
        self.pl3 = nn.MaxPool2d(2)
#         self.bn3 = nn.BatchNorm2d(32)

        self.cl4 = nn.Conv2d(128, 128, 3, padding=0)
        
#         self.ap = nn.AdaptiveAvgPool2d((1, 1))
        self.l1 = nn.Linear(6*128, 64)
#         self.l1 = nn.Linear(256, 32)
        self.l2 = nn.Linear(64, 1)

    def forward(self, x):
        # Flatten
        x = self.cl1(x)
        x = self.pl1(x)
#         x = self.bn1(x)
        x = torch.relu(x)
        
        x = self.cl2(x)
        x = self.pl2(x)
#         x = self.bn2(x)
        x = torch.relu(x)
        
        x = self.cl3(x)
        x = self.pl3(x)
#         x = self.bn3(x)
        x = torch.relu(x)
    
        x = self.cl4(x)
        x = torch.relu(x)
#         x = self.ap(x)
        x = x.view(x.size(0), -1)
        
        x = self.l1(x)
        x = torch.relu(x)
        x = self.l2(x)
    
        return x.view(-1)
    
def plot_trends(episode_durations, step_losses):
    plt.plot(smooth(episode_durations, 20))
    plt.title('Episode durations')
    plt.show()
    loss, v_loss, a_loss = zip(*step_losses)

    plt.plot(smooth(v_loss, 100))
    plt.title('Value loss')
    plt.show()
    plt.plot(smooth(a_loss, 100))
    plt.title('Actor loss')
    plt.show()
    
print("CUDA:", torch.cuda.is_available())
device = "cuda:0" if torch.cuda.is_available() else "cpu"
# device = "cpu"
policy = DeepPolicy().to(device=device)
critic = DeepCritic().to(device=device)
print(next(policy.parameters()).is_cuda)
filename = 'weights_ac.pt'

if os.path.isfile(filename):
    print(f"Loading weights from {filename}")
    weights = torch.load(filename)
    
    policy.load_state_dict(weights['policy'])
    critic.load_state_dict(weights['critic'])
    
else:
    # Train
    
    ### TODO some training here, maybe? Or run this on a different machine?    
    num_envs = 16
    max_steps = 10000
    max_episodes = 10000
    discount_factor = 0.99
    lr_actor = 1e-4
    lr_critic = 1e-3
    seed = 42

    envs = [CartPoleRawEnv() for i in range(num_envs)]

    for i, env in enumerate(envs):
        env.seed(seed + i)
    torch.manual_seed(seed)
    
    try:
        episode_durations, step_losses = run_episodes_actor_critic(policy.to(device=device), critic.to(device=device), envs, max_episodes, max_steps, discount_factor, lr_actor, lr_critic)
    except KeyboardInterrupt as err:
        for e in envs:
            e.close()
        raise err
    
    plot_trends(episode_durations, step_losses)
        
    print(f"Saving weights to {filename}")
    torch.save({
        # You can add more here if you need, e.g. critic
        'policy': policy.state_dict(),  # Always save weights rather than objects
        'critic': critic.state_dict(),  # Always save weights rather than objects
    },
    filename)
    
    plot_trends(episode_durations, step_losses)
    
def bonus_get_action(x):
    return policy(x.to(device=device)).exp().multinomial(1)[:, 0]
# Out:
# CUDA: False
# False
# Step 30, finished 23 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 15.826086956521738
# 			max episode duration: 28
# 		Avg Loss. Total: 0.6592438757419586; Actor: 0.5405106981595357; Critic: 0.38898853460947674
# Step 60, finished 44 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.5
# 			max episode duration: 56
# 		Avg Loss. Total: 0.768485814332962; Actor: 0.6248904625574748; Critic: 0.45604057908058165
# Step 90, finished 65 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.866666666666667
# 			max episode duration: 56
# 		Avg Loss. Total: 0.7346837421258291; Actor: 0.59786383608977; Critic: 0.4357518305381139
# Step 120, finished 84 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 23.366666666666667
# 			max episode duration: 71
# 		Avg Loss. Total: 0.7457772274812062; Actor: 0.6091005762418111; Critic: 0.44122693836689
# Step 150, finished 107 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.366666666666667
# 			max episode duration: 71
# 		Avg Loss. Total: 0.6968185931444169; Actor: 0.5651605119307835; Critic: 0.41423834264278414
# Step 180, finished 130 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 24.3
# 			max episode duration: 61
# 		Avg Loss. Total: 0.6834028581778209; Actor: 0.5593057165543238; Critic: 0.40374999940395356
# Step 210, finished 153 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.566666666666666
# 			max episode duration: 51
# 		Avg Loss. Total: 0.6701237400372823; Actor: 0.5421175936857859; Critic: 0.39906494120756786
# Step 240, finished 180 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.233333333333334
# 			max episode duration: 52
# 		Avg Loss. Total: 0.6456083337465922; Actor: 0.5275440394878388; Critic: 0.38183631698290504
# Step 270, finished 203 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.1
# 			max episode duration: 52
# 		Avg Loss. Total: 0.5845876435438792; Actor: 0.4702336927254995; Critic: 0.3494707966844241
# Step 300, finished 224 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.733333333333334
# 			max episode duration: 43
# 		Avg Loss. Total: 0.6067925006151199; Actor: 0.4846336245536804; Critic: 0.3644756908218066
# Step 330, finished 252 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.433333333333334
# 			max episode duration: 52
# 		Avg Loss. Total: 0.6125578433275223; Actor: 0.49344801902770996; Critic: 0.36583383778731027
# Step 360, finished 273 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.033333333333335
# 			max episode duration: 40
# 		Avg Loss. Total: 0.6257863988478979; Actor: 0.5081795791784922; Critic: 0.37169660727183024
# Step 390, finished 296 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.866666666666667
# 			max episode duration: 53
# 		Avg Loss. Total: 0.6295000632603963; Actor: 0.4961173286040624; Critic: 0.381441401441892
# Step 420, finished 315 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.9
# 			max episode duration: 53
# 		Avg Loss. Total: 0.642798391977946; Actor: 0.5039357513189315; Critic: 0.3908305128415426
# Step 450, finished 334 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 25.033333333333335
# 			max episode duration: 57
# 		Avg Loss. Total: 0.6520269393920899; Actor: 0.5210574100414912; Critic: 0.3914982368548711
# Step 480, finished 357 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21
/ 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.066666666666666
# 			max episode duration: 60
# 		Avg Loss. Total: 0.5033957093954087; Actor: 0.39723631540934246; Critic: 0.3047775482137998
# Step 9150, finished 6869 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 18.533333333333335
# 			max episode duration: 39
# 		Avg Loss. Total: 0.48643476168314614; Actor: 0.3904300292332967; Critic: 0.2912197455763817
# Step 9180, finished 6894 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.666666666666668
# 			max episode duration: 52
# 		Avg Loss. Total: 0.41445732216040293; Actor: 0.31747503131628035; Critic: 0.25571980476379397
# Step 9210, finished 6916 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 18.433333333333334
# 			max episode duration: 46
# 		Avg Loss. Total: 0.4774795373280843; Actor: 0.39510715901851656; Critic: 0.27992595930894215
# Step 9240, finished 6934 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 25.8
# 			max episode duration: 94
# 		Avg Loss. Total: 0.4582853813966115; Actor: 0.36957178860902784; Critic: 0.2734994868437449
# Step 9270, finished 6958 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 24.6
# 			max episode duration: 79
# 		Avg Loss. Total: 0.4692232439915339; Actor: 0.37533989051977795; Critic: 0.2815532957514127
# Step 9300, finished 6984 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 18.466666666666665
# 			max episode duration: 39
# 		Avg Loss. Total: 0.43261618514855704; Actor: 0.35013070156176884; Critic: 0.2575508380929629
# Step 9330, finished 7007 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 18.2
# 			max episode duration: 35
# 		Avg Loss. Total: 0.40152508616447447; Actor: 0.32944304794073104; Critic: 0.23680356591939927
# Step 9360, finished 7029 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.7
# 			max episode duration: 61
# 		Avg Loss. Total: 0.39219426612059277; Actor: 0.3182319621245066; Critic: 0.23307828803857167
# Step 9390, finished 7050 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.9
# 			max episode duration: 54
# 		Avg Loss. Total: 0.4325185964504878; Actor: 0.35399044503768284; Critic: 0.2555233761668205
# Step 9420, finished 7076 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.9
# 			max episode duration: 75
# 		Avg Loss. Total: 0.46563651065031686; Actor: 0.37642982602119446; Critic: 0.2774215946594874
# Step 9450, finished 7101 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.133333333333333
# 			max episode duration: 75
# 		Avg Loss. Total: 0.4126022358735402; Actor: 0.33548184235890705; Critic: 0.24486131419738133
# Step 9480, finished 7120 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.233333333333334
# 			max episode duration: 51
# 		Avg Loss. Total: 0.40828478038311006; Actor: 0.330974022547404; Critic: 0.24279777109622955
# Step 9510, finished 7141 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 25.366666666666667
# 			max episode duration: 66
# 		Avg Loss. Total: 0.4516797631978989; Actor: 0.37043542762597403; Critic: 0.2664620503783226
# Step 9540, finished 7161 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 24.2
# 			max episode duration: 53
# 		Avg Loss. Total: 0.4635038450360298; Actor: 0.3789551531275113; Critic: 0.2740262751777967
# Step 9570, finished 7186 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.2
# 			max episode duration: 49
# 		Avg Loss. Total: 0.44081687927246094; Actor: 0.3555312762657801; Critic: 0.26305124163627625
# Step 9600, finished 7205 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.633333333333333
# 			max episode duration: 34
# 		Avg Loss. Total: 0.43868537644545236; Actor: 0.36068760057290394; Critic: 0.2583415746688843
# Step 9630, finished 7221 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 23.633333333333333
# 			max episode duration: 54
# 		Avg Loss. Total: 0.527461243669192; Actor: 0.43429952959219614; Critic: 0.3103114793697993
# Step 9660, finished 7246 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 24.933333333333334
# 			max episode duration: 81
# 		Avg Loss. Total: 0.5336770276228587; Actor: 0.4185166279474894; Critic: 0.32441871563593544
# Step 9690, finished 7264 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.0
# 			max episode duration: 48
# 		Avg Loss. Total: 0.49085529446601867; Actor: 0.3971139053503672; Critic: 0.2922983417908351
# Step 9720, finished 7290 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.333333333333332
# 			max episode duration: 47
# 		Avg Loss. Total: 0.4683819591999054; Actor: 0.379350604613622; Critic: 0.2787066544095675
# Step 9750, finished 7312 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.866666666666667
# 			max episode duration: 55
# 		Avg Loss. Total: 0.4123574544986089; Actor: 0.3351108476519585; Critic: 0.24480202794075012
# Step 9780, finished 7334 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.466666666666665
# 			max episode duration: 68
# 		Avg Loss. Total: 0.44555138250192006; Actor: 0.3619803264737129; Critic: 0.2645612180233002
# Step 9810, finished 7353 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 24.433333333333334
# 			max episode duration: 68
# 		Avg Loss. Total: 0.47192833522955574; Actor: 0.3799503430724144; Critic: 0.281953160961469
# Step 9840, finished 7378 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.766666666666666
# 			max episode duration: 49
# 		Avg Loss. Total: 0.4456186552842458; Actor: 0.36712894290685655; Critic: 0.2620541820923487
# Step 9870, finished 7400 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.833333333333332
# 			max episode duration: 41
# 		Avg Loss. Total: 0.46477667689323426; Actor: 0.3889914333820343; Critic: 0.270280962685744
# Step 9900, finished 7415 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 21.666666666666668
# 			max episode duration: 59
# 		Avg Loss. Total: 0.4208019564549128; Actor: 0.3317481448252996; Critic: 0.2549278860290845
# Step 9930, finished 7444 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 22.166666666666668
# 			max episode duration: 55
# 		Avg Loss. Total: 0.4348672449588776; Actor: 0.3524623091022174; Critic: 0.25863608767588936
# Step 9960, finished 7469 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 20.0
# 			max episode duration: 56
# 		Avg Loss. Total: 0.44922903378804524; Actor: 0.36565084755420685; Critic: 0.2664036095142365
# Step 9990, finished 7489 / 10000 episodes. Last 30 episodes:
# 			avg episode duration: 19.966666666666665
# 			max episode duration: 36
# 		Avg Loss. Total: 0.408817332983017; Actor: 0.3319274793068568; Critic: 0.24285359779993693
# Saving weights to weights_ac.pt

# %%
for e in envs:
    e.close()

# %%
def bonus_get_action(x):
    return policy(x.to(device=device)).exp().multinomial(1)[:, 0]

# %%
seed = 42
episode_durations = []
for i in range(20):  # Not too many since it may take forever to render
    test_env = CartPoleRawEnv()
    test_env.seed(seed + i)
    state = test_env.reset()
    done = False
    steps = 0
    while not done:
        steps += 1
        with torch.no_grad():
            action = bonus_get_action(state).item()
        state, reward, done, _ = test_env.step(action)
    episode_durations.append(steps)
    test_env.close()

#REMOVED THE SMOOTHING SINCE HERE THERE ARE ONLY 20 EPISODES
plt.plot(episode_durations)
plt.title('Episode durations')
plt.show()

# %%
seed = 42
episode_durations = []
for i in range(20):  # Not too many since it may take forever to render
    test_env = CartPoleRawEnv()
    test_env.seed(seed + i)
    state = test_env.reset()
    done = False
    steps = 0
    while not done:
        steps += 1
        with torch.no_grad():
            action = bonus_get_action(state).item()
        state, reward, done, _ = test_env.step(action)
    episode_durations.append(steps)
    test_env.close()
    
plt.plot(smooth(episode_durations, 100))
plt.title('Episode durations')
plt.show()
